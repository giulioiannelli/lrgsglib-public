# %%
# %matplotlib inline
from LRGSG_package.LRGSG import *
#
move_to_rootf(print_tf=True)
# Out:
# cwd: /home/opisthofulax/PhD/projects/complex-networks/LRG-Signed

# %%
l = Lattice2D(side1=128,
              pflip=0.1,  
              pbc=False, 
              geo='hexagonal', 
              init_weight_dict=True, 
              with_positions=True)

# %%
x = 128*np.sqrt(3)
# Out:
# (221.70250336881628, 222, 1.7025033688162807)

# %%
l = Lattice2D(side1=128,
              pflip=0.1,  
              pbc=False, 
              geo='hexagonal', 
              init_weight_dict=True, 
              with_positions=True)
l.flip_sel_edges(l.neg_weights_dict['randZERR']['G'], on_graph='G')
l.flip_sel_edges(l.neg_weights_dict.get_links_rball(40), 'G')
# l.flip_sel_edges(l.neg_weights_dict['center']['G'])

# %%
fig, ax = plt.subplots(figsize=(20, 20))
ax.set_aspect('equal')
nx.draw(l.G, ax=ax, pos=nx.get_node_attributes(l.G, 'pos'), 
        node_size=1, 
        edge_color=['r' if w < 0 else 'lightblue' 
                    for u, v, w in list(l.G.edges(data='weight'))],
        # with_labels=True
        )

# %%
# Out:
# 'test: /test'
