# %%
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

# %%
G = nx.grid_2d_graph(30, 30, periodic=True)

# %%
adj = nx.laplacian_matrix(G).todense()
eigv, eigV = np.linalg.eigh(adj)

# %%
plt.hist(eigv, bins=10)
plt.show()

# %%
plt.imshow(adj)
plt.colorbar()
plt.show()
