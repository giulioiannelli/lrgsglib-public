# %%
# %matplotlib inline
#
from lrgsglib.core import *
#
move_to_rootf(print_tf=True)
# Out:
# Current working directory: /home/opisthofulax/PhD/projects/complex-networks/lrgsglib

# %%
sg = Lattice2D(100, pflip=.005
               , init_nw_dict=True)
# sg.flip_random_fract_edges()
sg.flip_sel_edges(sg.nwDict['rand']['G'])
# Out:
# {(0, 100): ((0, 0), (1, 0)), (0, 1): ((0, 0), (0, 1)), (0, 9900): ((0, 0), (99, 0)), (0, 99): ((0, 0), (0, 99)), (1, 101): ((0, 1), (1, 1)), (1, 2): ((0, 1), (0, 2)), (1, 9901): ((0, 1), (99, 1)), (2, 102): ((0, 2), (1, 2)), (2, 3): ((0, 2), (0, 3)), (2, 9902): ((0, 2), (99, 2)), (3, 103): ((0, 3), (1, 3)), (3, 4): ((0, 3), (0, 4)), (3, 9903): ((0, 3), (99, 3)), (4, 104): ((0, 4), (1, 4)), (4, 5): ((0, 4), (0, 5)), (4, 9904): ((0, 4), (99, 4)), (5, 105): ((0, 5), (1, 5)), (5, 6): ((0, 5), (0, 6)), (5, 9905): ((0, 5), (99, 5)), (6, 106): ((0, 6), (1, 6)), (6, 7): ((0, 6), (0, 7)), (6, 9906): ((0, 6), (99, 6)), (7, 107): ((0, 7), (1, 7)), (7, 8): ((0, 7), (0, 8)), (7, 9907): ((0, 7), (99, 7)), (8, 108): ((0, 8), (1, 8)), (8, 9): ((0, 8), (0, 9)), (8, 9908): ((0, 8), (99, 8)), (9, 109): ((0, 9), (1, 9)), (9, 10): ((0, 9), (0, 10)), (9, 9909): ((0, 9), (99, 9)), (10, 110): ((0, 10), (1, 10)), (10, 11): ((0, 10), (0, 11)), (10, 9910): ((0, 10), (99, 10)), (11, 111): ((0, 11), (1, 11)), (1
# ...

# %%
sg.compute_k_eigvV(howmany=10)

# %%
plt.imshow(sg.eigV[-1].reshape(sg.syshape), cmap='hot', interpolation='none')
plt.colorbar()

# %%
sg.nflip, sg.Ne, sg.Ne_n, sg.fleset
# Out:
# (2000,
#  20000,
#  2000,
#  {'H': [((0, 3), (1, 3)),
#    ((0, 9), (0, 10)),
#    ((0, 10), (0, 11)),
#    ((0, 12), (1, 12)),
#    ((0, 15), (1, 15)),
#    ((0, 19), (1, 19)),
#    ((0, 21), (0, 22)),
#    ((0, 29), (99, 29)),
#    ((0, 30), (99, 30)),
#    ((0, 31), (0, 32)),
#    ((0, 34), (0, 35)),
#    ((0, 35), (1, 35)),
#    ((0, 46), (0, 47)),
#    ((0, 49), (99, 49)),
#    ((0, 52), (0, 53)),
#    ((0, 56), (0, 57)),
#    ((0, 56), (99, 56)),
#    ((0, 57), (1, 57)),
#    ((0, 57), (0, 58)),
#    ((0, 57), (99, 57)),
#    ((0, 58), (0, 59)),
#    ((0, 59), (99, 59)),
#    ((0, 66), (0, 67)),
#    ((0, 67), (0, 68)),
#    ((0, 68), (0, 69)),
#    ((0, 69), (99, 69)),
#    ((0, 73), (0, 74)),
#    ((0, 74), (1, 74)),
#    ((0, 79), (1, 79)),
#    ((0, 80), (1, 80)),
#    ((0, 91), (0, 92)),
#    ((0, 97), (1, 97)),
#    ((1, 0), (1, 1)),
#    ((1, 1), (2, 1)),
#    ((1, 4), (1, 5)),
#    ((1, 19), (1, 20)),
#    ((1, 29), (1, 30)),
#    ((1, 31), (2, 31)),
# ...

# %%
sg = SignedGraph(nx.barabasi_albert_graph(100, 2), pflip=0.1)
